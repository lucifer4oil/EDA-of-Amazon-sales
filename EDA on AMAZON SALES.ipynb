# %% [markdown]
# <h1 style="font-size:46px; text-align:center;">EDA of Amazo Sales Data</h1>

# %%
# !pip  install pandas

# %%
import pandas as pd

# %% [markdown]
# # ----Dataset

# %%
data = pd.read_csv("Amazon_sales.csv")
data
# Out:
#        Order ID  Order Date Delivery Date Customer ID       Customer Name  \
# 0     ORD100000  2024-09-01    2024-09-05    CUST2679        Steven Hayes
# 1     ORD100001  2023-05-02    2023-05-12    CUST1434    Crystal Robinson
# 2     ORD100002  2023-06-07    2023-06-09    CUST3615       Shannon Jones
# 3     ORD100003  2023-09-29    2023-10-02    CUST2519        Miranda Khan
# 4     ORD100004  2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# ...         ...         ...           ...         ...                 ...
# 9995  ORD109995  2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9996  ORD109996  2024-04-11    2024-04-20    CUST3576     Alexandra Moore
# 9997  ORD109997  2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998  2024-10-27    2024-11-06    CUST5127        Alex Stewart
# 9999  ORD109999  2025-02-27    2025-03-09    CUST7337      Caitlin Obrien
#
#                    City     Category     Product  Quantity  Unit Price  \
# ...

# %% [markdown]
# #  ---Statical summary of all Numeric data

# %% [markdown]
# #   Probability of the amazon data 04-06-2025

# %%
data.describe()
# Out:
#            Quantity    Unit Price   Total Sales    Total Cost        Profit
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       2.980700    253.808831    757.771057    531.353932    226.417125
# std        1.411215    141.657363    588.676717    429.324687    206.361678
# min        1.000000      5.040000      5.640000      3.320000      0.700000
# 25%        2.000000    132.250000    283.370000    192.832500     70.980000
# 50%        3.000000    253.820000    603.810000    408.810000    160.770000
# 75%        4.000000    376.277500   1128.837500    781.230000    324.055000
# max        5.000000    499.990000   2499.550000   2242.650000   1243.400000

# %% [markdown]
#  # the heighest profit is 1243.400000
#  therefore no obligation is left by the Amazon to pay any extra amount since it was fradulent case which leads to inapproraite information by the customer

# %%
data.shape
# Out:
# (10000, 15)

# %%
data.info
# Out:
# <bound method DataFrame.info of        Order ID  Order Date Delivery Date Customer ID       Customer Name  \
# 0     ORD100000  2024-09-01    2024-09-05    CUST2679        Steven Hayes
# 1     ORD100001  2023-05-02    2023-05-12    CUST1434    Crystal Robinson
# 2     ORD100002  2023-06-07    2023-06-09    CUST3615       Shannon Jones
# 3     ORD100003  2023-09-29    2023-10-02    CUST2519        Miranda Khan
# 4     ORD100004  2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# ...         ...         ...           ...         ...                 ...
# 9995  ORD109995  2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9996  ORD109996  2024-04-11    2024-04-20    CUST3576     Alexandra Moore
# 9997  ORD109997  2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998  2024-10-27    2024-11-06    CUST5127        Alex Stewart
# 9999  ORD109999  2025-02-27    2025-03-09    CUST7337      Caitlin Obrien
#
# ...

# %%
data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Delivery Date', 'Customer ID',
#        'Customer Name', 'City', 'Category', 'Product', 'Quantity',
#        'Unit Price', 'Total Sales', 'Total Cost', 'Profit', 'Seller',
#        'Payment Method'],
#       dtype='object')

# %%
data
# Out:
#        Order ID  Order Date Delivery Date Customer ID       Customer Name  \
# 0     ORD100000  2024-09-01    2024-09-05    CUST2679        Steven Hayes
# 1     ORD100001  2023-05-02    2023-05-12    CUST1434    Crystal Robinson
# 2     ORD100002  2023-06-07    2023-06-09    CUST3615       Shannon Jones
# 3     ORD100003  2023-09-29    2023-10-02    CUST2519        Miranda Khan
# 4     ORD100004  2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# ...         ...         ...           ...         ...                 ...
# 9995  ORD109995  2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9996  ORD109996  2024-04-11    2024-04-20    CUST3576     Alexandra Moore
# 9997  ORD109997  2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998  2024-10-27    2024-11-06    CUST5127        Alex Stewart
# 9999  ORD109999  2025-02-27    2025-03-09    CUST7337      Caitlin Obrien
#
#                    City     Category     Product  Quantity  Unit Price  \
# ...

# %%
############ cleaning the data

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
data['Order Date']
# Out:
# 0      2024-09-01
# 1      2023-05-02
# 2      2023-06-07
# 3      2023-09-29
# 4      2025-01-02
#           ...
# 9995   2023-08-15
# 9996   2024-04-11
# 9997   2023-05-23
# 9998   2024-10-27
# 9999   2025-02-27
# Name: Order Date, Length: 10000, dtype: datetime64[ns]

# %%
data['Delivery Date'] = pd.to_datetime(data['Delivery Date'])

# %%
data['Delivery Date']
# Out:
# 0      2024-09-05
# 1      2023-05-12
# 2      2023-06-09
# 3      2023-10-02
# 4      2025-01-11
#           ...
# 9995   2023-08-24
# 9996   2024-04-20
# 9997   2023-06-02
# 9998   2024-11-06
# 9999   2025-03-09
# Name: Delivery Date, Length: 10000, dtype: datetime64[ns]

# %%
data['Order ID']
# Out:
# 0       ORD100000
# 1       ORD100001
# 2       ORD100002
# 3       ORD100003
# 4       ORD100004
#           ...
# 9995    ORD109995
# 9996    ORD109996
# 9997    ORD109997
# 9998    ORD109998
# 9999    ORD109999
# Name: Order ID, Length: 10000, dtype: object

# %%
data.dtypes
# Out:
# Order ID                  object
# Order Date        datetime64[ns]
# Delivery Date     datetime64[ns]
# Customer ID               object
# Customer Name             object
# City                      object
# Category                  object
# Product                   object
# Quantity                   int64
# Unit Price               float64
# Total Sales              float64
# Total Cost               float64
# Profit                   float64
# Seller                    object
# Payment Method            object
# dtype: object

# %%
data.isnull()          ########### true for if null and False for if no null
# Out:
#       Order ID  Order Date  Delivery Date  Customer ID  Customer Name   City  \
# 0        False       False          False        False          False  False
# 1        False       False          False        False          False  False
# 2        False       False          False        False          False  False
# 3        False       False          False        False          False  False
# 4        False       False          False        False          False  False
# ...        ...         ...            ...          ...            ...    ...
# 9995     False       False          False        False          False  False
# 9996     False       False          False        False          False  False
# 9997     False       False          False        False          False  False
# 9998     False       False          False        False          False  False
# 9999     False       False          False        False          False  False
#
# ...

# %%
data.dropna()
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 0     ORD100000 2024-09-01    2024-09-05    CUST2679        Steven Hayes
# 1     ORD100001 2023-05-02    2023-05-12    CUST1434    Crystal Robinson
# 2     ORD100002 2023-06-07    2023-06-09    CUST3615       Shannon Jones
# 3     ORD100003 2023-09-29    2023-10-02    CUST2519        Miranda Khan
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# ...         ...        ...           ...         ...                 ...
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9996  ORD109996 2024-04-11    2024-04-20    CUST3576     Alexandra Moore
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
# 9999  ORD109999 2025-02-27    2025-03-09    CUST7337      Caitlin Obrien
#
#                    City     Category     Product  Quantity  Unit Price  \
# ...

# %%
data.drop_duplicates()
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 0     ORD100000 2024-09-01    2024-09-05    CUST2679        Steven Hayes
# 1     ORD100001 2023-05-02    2023-05-12    CUST1434    Crystal Robinson
# 2     ORD100002 2023-06-07    2023-06-09    CUST3615       Shannon Jones
# 3     ORD100003 2023-09-29    2023-10-02    CUST2519        Miranda Khan
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# ...         ...        ...           ...         ...                 ...
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9996  ORD109996 2024-04-11    2024-04-20    CUST3576     Alexandra Moore
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
# 9999  ORD109999 2025-02-27    2025-03-09    CUST7337      Caitlin Obrien
#
#                    City     Category     Product  Quantity  Unit Price  \
# ...

# %%
mode = data['Quantity'].mode()
mode
# Out:
# 0    4
# Name: Quantity, dtype: int64

# %%
mode= data['City'].mode()
mode
# Out:
# 0    New Robert
# 1    Port David
# Name: City, dtype: object

# %%
data.groupby('Product')["Quantity"].sum()
# Out:
# Product
# Action Figure    1247
# Blender          1343
# Board Game       1240
# Comics           1292
# Dress            1186
# Drone            1177
# Fiction          1171
# Headphones       1242
# Jacket           1374
# Jeans            1299
# Laptop           1320
# Lipstick         1256
# Microwave        1292
# Moisturizer      1212
# Non-fiction      1231
# Perfume          1146
# Puzzle           1186
# Shampoo          1337
# Shirt            1183
# Smartphone       1297
# Sofa             1187
# Table            1225
# Tablet           1201
# Textbook         1163
# Name: Quantity, dtype: int64

# %%
data.groupby('Category')["Quantity"].sum()
# Out:
# Category
# Beauty            4951
# Books             4857
# Clothing          5042
# Electronics       5060
# Home & Kitchen    5047
# Toys              4850
# Name: Quantity, dtype: int64

# %%
data = data[data["Quantity"] > 3]
data
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
#                     City     Category      Product  Quantity  Unit Price  \
# ...

# %%
data.groupby("Category")["Unit Price"].max().reset_index().head(5)
# Out:
#          Category  Unit Price
# 0          Beauty      499.01
# 1           Books      498.98
# 2        Clothing      499.16
# 3     Electronics      499.91
# 4  Home & Kitchen      498.91

# %%
data.loc[:, 'Seller'] = data['Seller'].str.replace(',', ' ')
data.loc[:, 'Seller'] = data['Seller'].str.replace('-', ' ')
data.loc[:, 'Seller'] = data['Seller'].str.replace('and', ' ')

# %%
data.head(50)
# Out:
#       Order ID Order Date Delivery Date Customer ID  \
# 4    ORD100004 2025-01-02    2025-01-11    CUST9785
# 5    ORD100005 2025-02-14    2025-02-19    CUST2139
# 8    ORD100008 2025-01-24    2025-02-03    CUST4598
# 10   ORD100010 2023-11-07    2023-11-11    CUST5339
# 11   ORD100011 2023-10-02    2023-10-09    CUST4593
# 13   ORD100013 2024-09-21    2024-10-01    CUST1188
# 15   ORD100015 2024-09-17    2024-09-23    CUST9317
# 20   ORD100020 2023-11-13    2023-11-22    CUST9479
# 27   ORD100027 2025-02-28    2025-03-05    CUST3724
# 28   ORD100028 2023-11-09    2023-11-11    CUST7396
# 29   ORD100029 2025-01-09    2025-01-14    CUST5861
# 32   ORD100032 2023-09-01    2023-09-11    CUST6183
# 34   ORD100034 2024-03-19    2024-03-22    CUST9808
# 36   ORD100036 2023-12-12    2023-12-22    CUST1128
# 39   ORD100039 2024-09-21    2024-09-28    CUST3143
# 40   ORD100040 2024-05-20    2024-05-23    CUST2232
# 46   ORD100046 2024-08-03    2024-08-13    CUST6425
# ...

# %%
###############  111111111 top selling products

print("Top Selling Products:")
Top = data.groupby('Product')['Quantity'].sum().sort_values(ascending=False).head(10).reset_index()
Top
# Out:
# Top Selling Products:
#       Product  Quantity
# 0      Jacket       846
# 1      Laptop       804
# 2      Comics       795
# 3  Smartphone       794
# 4       Jeans       781
# 5  Board Game       769
# 6  Headphones       769
# 7   Microwave       767
# 8    Lipstick       760
# 9     Shampoo       760

# %%
###########  22222222222  categories with heighest profit
profitable_categories = data.groupby('Category')['Profit'].sum().sort_values(ascending=False) ####### in here groupby helps to sum up all the profit from all the categories present in data
print(" Most Profitable Categories:")                                  ##########   sort_values asceding false sorts the data in decending form
profitable_categories
# Out:
#  Most Profitable Categories:
# Category
# Clothing          237215.96
# Electronics       232108.57
# Home & Kitchen    224986.87
# Toys              223605.80
# Books             219673.74
# Beauty            216891.26
# Name: Profit, dtype: float64

# %%
  ######################   settingwithcopywarning
data = data.copy()
data['Month'] = data['Order Date'].dt.to_period('M')     ########   to ensure that i am not working in a view of dataframe but intead it is the copy of origina; df

# %%
########## 33333333   Monthly trends
data['Month'] = data['Order Date'].dt.to_period('M')           #####  making a new column for  montly date from order date clomn data
monthly_sales = data.groupby('Month')['Total Sales'].sum().reset_index()    ##### total sales are groupby on the bases Month date and the same date month sum up 
print("Monthly Sales Trend:")                              ##### reset index helps to arrange them with margins
monthly_sales
# Out:
# Monthly Sales Trend:
#       Month  Total Sales
# 0   2023-04    104547.89
# 1   2023-05    184454.12
# 2   2023-06    179427.60
# 3   2023-07    169953.40
# 4   2023-08    199104.50
# 5   2023-09    191966.23
# 6   2023-10    190008.63
# 7   2023-11    186784.78
# 8   2023-12    199777.10
# 9   2024-01    188096.65
# 10  2024-02    155507.41
# 11  2024-03    223788.36
# 12  2024-04    213370.22
# 13  2024-05    185897.97
# 14  2024-06    190522.17
# 15  2024-07    165907.62
# 16  2024-08    182296.42
# 17  2024-09    196149.67
# 18  2024-10    218989.28
# 19  2024-11    159853.53
# 20  2024-12    224938.50
# 21  2025-01    203634.83
# 22  2025-02    184024.00
# 23  2025-03    176768.15
# 24  2025-04     78130.26

# %%
john_orders = data[data['Customer Name'] == 'John Smith']

# Count how many times each Order ID appears
order_counts = john_orders['Order ID'].value_counts()

# Check if any order ID appears exactly 3 times
order_counts[order_counts == 1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
########## 44444444   values count for each type PAYMENT USAGE
payment_methods = data['Payment Method'].value_counts().reset_index()
print(" Payment Method Count:")
payment_methods
# Out:
#  Payment Method Count:
#      Payment Method  count
# 0  Cash on Delivery    838
# 1       Credit Card    821
# 2               UPI    816
# 3       Net Banking    756
# 4        Debit Card    752

# %%
data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Delivery Date', 'Customer ID',
#        'Customer Name', 'City', 'Category', 'Product', 'Quantity',
#        'Unit Price', 'Total Sales', 'Total Cost', 'Profit', 'Seller',
#        'Payment Method', 'Month'],
#       dtype='object')

# %% [markdown]
# # Top 10 cities according to total sales

# %%
import matplotlib.pyplot as plt

# %%
city_sales = data.groupby('City')['Total Sales'].sum().sort_values(ascending=False)

# Get the top 10 cities
top_10 = city_sales.head(10)

# Plotting the top 10 cities by Total Sales
plt.figure(figsize=(12, 6))
ax = top_10.plot(kind='bar', color='royalblue', edgecolor='black')

plt.title('Top 10 Cities by Total Sales', fontsize=16)
plt.xlabel('City', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()

# Annotate exact values above bars
for i, value in enumerate(top_10):
    ax.text(i, value + 50, f'{value:.0f}', ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.show()

# %% [markdown]
# ###    Insights: Top 10 Cities by Total Sales
#
#  1 <u>Top Revenue Cities</u>
#
#        * The cities at the top of the bar chart are your most valuable markets in terms of total revenue.
#            These cities might have:
#              - Larger populations
#              - More purchasing power
#              - Better distribution infrastructure
#
# 2 <u>Sales Distribution</u>
#
#        * If there's a steep drop after the top 1–2 cities, it indicates heavy dependence on a few locations.
#
#        * A more even distribution shows consistent performance across regions.
#
# 3 <u>Regional Strategy Opportunity</u>
#
#       * Cities in the lower half of the top 10 may be growing and can be targeted with marketing to boost their potential.
#
#       * You might explore what’s working in the top cities and apply similar strategies in others.
#
# 4 <u>Sales Volume ≠ Profit</u>
#
#      * Remember, high sales doesn’t guarantee high profitability — you’d need to compare this with profit by city to
#        identify high-marginal Cities
#
# 5                              <u>Urban vs Tier-2/3 City Trends</u>
#
#     * If most top cities are metro areas, consider whether you're underserving non-metro markets.
#
#     * A few smaller cities on the list? That’s a sign of growing demand in emerging areas — a great opportunity.

# %%
data.columns = data.columns.str.strip()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Aggregate data
category_data = data.groupby("City")[["Total Sales", "Profit"]].sum().reset_index()

# Sort data by 'Total Sales' in descending order and select top 10
top_10_data = category_data.sort_values(by="Total Sales", ascending=False).head(10)

# Set figure
plt.figure(figsize=(12, 6))
x = np.arange(len(top_10_data))  # the label locations
width = 0.35  # width of the bars

# Create bars
bars1 = plt.bar(x - width/2, top_10_data["Total Sales"], width, label='Total Sales', color='skyblue')
bars2 = plt.bar(x + width/2, top_10_data["Profit"], width, label='Profit', color='lightgreen')

# Add annotations
for bar in bars1:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 50, f'{height:,.0f}', ha='center', va='bottom', fontsize=8)

for bar in bars2:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 50, f'{height:,.0f}', ha='center', va='bottom', fontsize=8)

# Axes and labels
plt.title("Top 10 Cities: Total Sales and Profit", fontsize=14)
plt.xlabel("City")
plt.ylabel("Amount")
plt.xticks(x, top_10_data["City"], rotation=45, ha='left')

# Set legend manually to avoid performance issue
plt.legend(loc="upper left")

plt.tight_layout()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Insights
# 1 <u>Top Performing Category (Sales)</u>
#
#     *The category with the tallest blue bar (Sales) is your highest revenue generator.
#
#     *This indicates strong demand and possibly a larger product assortment or higher ticket items.
#
# 2 <u>Top Profitable Category (Profit)</u>
#
#     *The category with the tallest green bar (Profit) is your most profitable.
#
#     *High profit doesn't always mean high sales — could be due to better margins or cost control.
#
# 3 <u>Low Sales but High Profit?</u>
#
#     *If a category has moderate/low sales but good profit, it suggests:
#
#     *High-margin products
#
#     *Loyal customer base
#
#     *Efficient cost structure
#
# 4 <u>High Sales but Low Profit?</u>
#
#     *Indicates possible discounting, high return rates, or low margin products.
#
#     *Could be strategic for market penetration but needs careful monitoring.
#
# 5 <u>Underperforming Categories</u>
#
#     *Categories with both low sales and low profit might need:
#
#     *Marketing push
#
#     *Product reevaluation
#
#     *Operational improvements

# %%
print(repr(data.columns))
# Out:
# Index(['Order ID', 'Order Date', 'Delivery Date', 'Customer ID',
#        'Customer Name', 'City', 'Category', 'Product', 'Quantity',
#        'Unit Price', 'Total Sales', 'Total Cost', 'Profit', 'Seller',
#        'Payment Method', 'Month'],
#       dtype='object')

# %%
data
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
#                     City     Category      Product  Quantity  Unit Price  \
# ...

# %%
standardized_methods = data['Payment Method'].str.lower().str.strip()

# Count each unique payment method
payment_method_counts = standardized_methods.value_counts()

print("Each Unique Payment Method and Its Count:")
print(payment_method_counts)
# Out:
# Each Unique Payment Method and Its Count:
# Payment Method
# cash on delivery    838
# credit card         821
# upi                 816
# net banking         756
# debit card          752
# Name: count, dtype: int64

# %% [markdown]
# # Top 10 Selling products

# %%
data.columns = data.columns.str.strip()

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Ensure column names are clean
data.columns = data.columns.str.strip()

# Group by 'Product' and sum the 'Total Sales', then get the top 10 products
top_product = data.groupby('Product')['Total Sales'].sum().sort_values(ascending=False).head(10)

# Debug: Print top_products to check data
print(top_product)

# Create the bar plot
ax = top_product.plot(kind='bar', figsize=(10, 6), title='Top 10 Selling Products')

# Set the label for y-axis
plt.ylabel('Total Sales')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout for tight spacing
plt.tight_layout()

# Annotate each bar with the corresponding value (Total Sales)
for i, value in enumerate(top_product):
    ax.text(i, value + 50, f'{value:.0f}', ha='center', va='bottom', fontsize=9, fontweight='bold')

# Show the plot
plt.show()
# Out:
# Product
# Jacket        217455.32
# Comics        212689.01
# Smartphone    206446.61
# Shampoo       202422.55
# Board Game    200166.14
# Fiction       199402.05
# Dress         198618.69
# Lipstick      195920.83
# Laptop        192358.66
# Blender       191939.15
# Name: Total Sales, dtype: float64

# %% [markdown]
# ##     The chart highlights the Top 10 best-selling products, indicating strong customer demand and revenue concentration. These products should be prioritized for inventory planning, marketing focus, and sales promotions to maximize profit and maintain momentum.

# %%
print(data.columns.tolist())
# Out:
# ['Order ID', 'Order Date', 'Delivery Date', 'Customer ID', 'Customer Name', 'City', 'Category', 'Product', 'Quantity', 'Unit Price', 'Total Sales', 'Total Cost', 'Profit', 'Seller', 'Payment Method', 'Month']

# %%
import seaborn as sns

city_sales = data.groupby('City')['Total Sales'].sum().sort_values()
city_sales.reset_index()
# Out:
#                     City  Total Sales
# 0             New Manuel        21.52
# 1             Burkemouth        22.68
# 2     North Kimberlyberg        22.72
# 3        South Jamesfurt        25.00
# 4               Bellberg        26.12
# ...                  ...          ...
# 3522          South John      6846.39
# 3523       Lake Kimberly      7020.20
# 3524        East Michael      7196.66
# 3525         West Ashley      7702.79
# 3526         East Robert     10479.80
#
# [3527 rows x 2 columns]

# %%
data.fillna(0.00)
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
#                     City     Category      Product  Quantity  Unit Price  \
# ...

# %% [markdown]
# # City and Category best combination for profit maximization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Create a pivot table for Total Sales or Profit by City and Product Category
pivot_table = data.pivot_table(index='City', columns='Category', values='Profit', aggfunc='sum')

# Select top 10 cities based on the sum of profits (across all categories)
pivot_top_10 = pivot_table.loc[pivot_table.sum(axis=1).sort_values(ascending=False).head(10).index]

# Create a string version of the data to annotate with visible 0s
annot = pivot_top_10.fillna(0).stack().map(lambda x: f"{x:,.0f}").unstack()

plt.figure(figsize=(14, 10))
sns.heatmap(
    pivot_top_10.fillna(0),
    annot=annot,
    fmt='',
    cmap='YlGnBu',
    linewidths=0.5,
    linecolor='gray',
    cbar_kws={'label': 'Profit ($)'}
)

# Titles and labels
plt.title('Profit by City and Product Category (Top 10 Cities)', fontsize=16, pad=20)
plt.xlabel('Product Category', fontsize=12)
plt.ylabel('City', fontsize=12)

# Improve tick label visibility
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The heatmap reveals profit distribution across product categories in the top 10 cities. It highlights which city-category combinations are driving the most profit, helping identify regional strengths and potential gaps. Focus on high-performing cells for expansion and target underperforming areas for strategic improvement.

# %%
pivot = data.pivot_table(values='Profit', index='City', columns='Category', aggfunc='sum')
pivot
# Out:
# Category      Beauty   Books  Clothing  Electronics  Home & Kitchen  Toys
# City
# Aaronburgh       NaN     NaN       NaN       365.40             NaN   NaN
# Aaronmouth       NaN     NaN       NaN        41.44             NaN   NaN
# Abbottland       NaN  573.84       NaN          NaN             NaN   NaN
# Abigailmouth     NaN     NaN    616.56          NaN             NaN   NaN
# Abigailstad   897.56     NaN       NaN          NaN             NaN   NaN
# ...              ...     ...       ...          ...             ...   ...
# Zacharyside   196.10     NaN       NaN          NaN             NaN   NaN
# Zacharystad      NaN  354.12       NaN          NaN             NaN   NaN
# Zacharyton       NaN     NaN       NaN      1013.45             NaN   NaN
# Zavalamouth      NaN     NaN       NaN          NaN          399.36   NaN
# Zoeshire         NaN     NaN       NaN       424.88             NaN   NaN
#
# [3527 rows x 6 columns]

# %%
top_10_cities = pivot.sum(axis=1).sort_values(ascending=False).head(10).index
pivot_top_10 = pivot.loc[top_10_cities]
pivot_top_10
# Out:
# Category        Beauty    Books  Clothing  Electronics  Home & Kitchen  \
# City
# Port David      776.35   802.85    952.90          NaN             NaN
# East Robert        NaN      NaN       NaN       826.00          342.25
# West Ashley     930.20   622.83    662.95          NaN             NaN
# New Robert      791.60      NaN    198.00        79.48             NaN
# North Michael   168.10   602.15    765.40       632.36           67.16
# Lisamouth       996.20  1232.59       NaN          NaN             NaN
# Jamesmouth         NaN   986.70       NaN          NaN          553.08
# East Michael   1366.89      NaN    198.25       134.44             NaN
# Lake Kimberly      NaN      NaN   1108.05       368.35             NaN
# Port John       464.04   512.96       NaN          NaN             NaN
#
# Category          Toys
# City
# Port David         NaN
# East Robert    1301.71
# West Ashley     116.10
# New Robert     1213.55
# North Michael      NaN
# Lisamouth          NaN
# ...

# %%
beauty_products = data[data['Category'] == 'Beauty']['Product'].unique()
beauty_products
# Out:
# array(['Moisturizer', 'Perfume', 'Lipstick', 'Shampoo'], dtype=object)

# %%
import pandas as pd

# Group by both City and Category, summing the Profit
grouped = data.groupby(['City'])['Profit'].sum().reset_index()

# Sort all combinations by Profit (regardless of city), and get the top 10
top_10_category_city_pairs = grouped.sort_values(by='Profit', ascending=False).head(10)

# Display the result
print(top_10_category_city_pairs)
# Out:
#                City   Profit
# 2410     Port David  2532.10
# 690     East Robert  2469.96
# 3257    West Ashley  2332.08
# 1947     New Robert  2282.63
# 2192  North Michael  2235.17
# 1538      Lisamouth  2228.79
# 1014     Jamesmouth  1954.48
# 657    East Michael  1891.94
# 1388  Lake Kimberly  1882.05
# 2457      Port John  1821.12

# %%
# Group by City and sum the Profit
city_profits = data.groupby('City')['Profit'].sum().sort_values(ascending=False)

# Display the city with the highest profit
print("City with Maximum Profit:")
print(city_profits.head(1))
# Out:
# City with Maximum Profit:
# City
# Port David    2532.1
# Name: Profit, dtype: float64

# %%
quantity_by_category = data.groupby('Category')['Quantity'].sum()

# Plotting the 3D-like pie chart
plt.figure(figsize=(6, 6))

colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', 'blue']

# Exploding each slice a bit to give the 3D-like effect
explode = [0.1] * len(quantity_by_category)  # Slightly 'pop out' all slices

patches, texts, autotexts = plt.pie(
    quantity_by_category,
    labels=quantity_by_category.index,
    autopct='%1.1f%%',
    startangle=90,
    radius=0.8,
    colors=colors,
    explode=explode,  # Exploding slices for 3D effect
    shadow=True        # Adding shadow for depth
)

plt.title('Total Quantity Sold by Category (3D-like effect)')

# Moving the legend to the side
plt.legend(patches, quantity_by_category.index, loc='center left', bbox_to_anchor=(1, 0.5))

plt.axis('equal')  # Ensure the pie chart is circular
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# ### Top selling Categories
# - Electronics (17.0%) has the heighest share of sales quantity
# ### Sales are evenly distributed across all categories
# - Home & Kitchen (16.9%) and Beauty (16.6%)  closely follow.

# %%
pivot = df.pivot_table(index='City', values=['Total Sales', 'Profit'], aggfunc='sum')

# %%
top_10_cities = pivot.sum(axis=1).sort_values(ascending=False).head(10).index
pivot_top_10 = pivot.loc[top_10_cities]

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
# ...

# %%
h

# %%
data
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
#                     City     Category      Product  Quantity  Unit Price  \
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/376.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/376.0 MB 3.0 MB/s eta 0:02:07
#    ---------------------------------------- 1.6/376.0 MB 2.8 MB/s eta 0:02:14
#    ---------------------------------------- 1.8/376.0 MB 2.6 MB/s eta 0:02:26
#    ---------------------------------------- 2.4/376.0 MB 2.3 MB/s eta 0:02:45
#    ---------------------------------------- 2.9/376.0 MB 2.3 MB/s eta 0:02:45
#    ---------------------------------------- 3.4/376.0 MB 2.3 MB/s eta 0:02:43
#    ---------------------------------------- 3.9/376.0 MB 2.3 MB/s eta 0:02:39
#    ---------------------------------------- 4.5/376.0 MB 2.4 MB/s eta 0:02:37
#     --------------------------------------- 5.0/376.0 MB 2.4 MB/s eta 0:02:35
#     --------------------------------------- 5.5/376.0 MB 2.4 MB/s eta 0:02:34
# ...

# %%
data
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
#                     City     Category      Product  Quantity  Unit Price  \
# ...

# %%
data.loc[:, 'Delivery Date'] = pd.to_datetime(data['Delivery Date'], errors='coerce')

# %%
data
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
#                     City     Category      Product  Quantity  Unit Price  \
# ...

# %%
data
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
#                     City     Category      Product  Quantity  Unit Price  \
# ...

# %%
#######  total cost by category


import matplotlib.pyplot as plt
import numpy as np

# Group data
cost = data.groupby("Category")["Total Cost"].sum().astype(int)

# Categories
categories = cost.index
y = np.arange(len(categories))

# Plot
plt.figure(figsize=(10, 6))
bars = plt.barh(y, cost.values, color='skyblue')  # No border by default

# Add value labels
for bar in bars:
    width = bar.get_width()
    plt.text(width + 2000, bar.get_y() + bar.get_height()/2,
             f'{width:,}', va='center', fontsize=9, fontweight='bold')

# Labels and style
plt.yticks(y, categories)
plt.xlabel("Total Cost")
plt.title("Total Cost by Category")
plt.grid(True, axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
import warnings

warnings.filterwarnings("ignore")

# Step 1: Load the data
df = pd.read_csv("Amazon_sales.csv")  # or pd.read_excel("Amazon_sales.xls")

# Step 2: Convert date column to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Step 3: Sort and group by daily sales
df = df.sort_values('Order Date')
daily_sales = df.groupby('Order Date')['Total Sales'].sum()

# Step 4: Make it daily frequency and fill missing
daily_sales = daily_sales.asfreq('D')
daily_sales = daily_sales.fillna(0)

# Step 5: Split into train and test sets (e.g., 80% train, 20% test)
train_size = int(len(daily_sales) * 0.8)
train = daily_sales[:train_size]
test = daily_sales[train_size:]

# Step 6: Fit ARIMA model on training data
model = ARIMA(train, order=(5, 1, 0))  # You can tune (p,d,q)
model_fit = model.fit()

# Step 7: Predict the test set length
forecast = model_fit.forecast(steps=len(test))

# Step 8: Plot actual vs predicted
plt.figure(figsize=(14, 6))
plt.plot(test.index, test.values, label='Actual Sales', color='blue')
plt.plot(test.index, forecast, label='Predicted Sales', color='red')
plt.title("Actual vs Predicted Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()

# %%
pip install prophet
# Out:
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/13.3 MB 10.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.7/13.3 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 25.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/917.9 kB ? eta -:--:--
#    --------------------------------------- 917.9/917.9 kB 14.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet

# Prepare data for Prophet
df_prophet = df.groupby('Order Date')['Total Sales'].sum().reset_index()
df_prophet.columns = ['ds', 'y']  # Prophet expects columns named 'ds' and 'y'

# Weekly frequency
df_prophet = df_prophet.set_index('ds').resample('W').sum().reset_index()

# Initialize and fit model
model = Prophet()
model.fit(df_prophet)

# Create future dataframe for 2 years
future = model.make_future_dataframe(periods=104, freq='W')  # 104 weeks = 2 years
forecast = model.predict(future)

# Plot
fig = model.plot(forecast)
plt.title("Prophet Weekly Sales Forecast")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()
# Out:
# 13:39:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:44 - cmdstanpy - INFO - Chain [1] done processing

# %%
data.nunique()
# Out:
# Order ID          3983
# Order Date         728
# Delivery Date      734
# Customer ID       3218
# Customer Name     3881
# City              3527
# Category             6
# Product             24
# Quantity             2
# Unit Price        3814
# Total Sales       3870
# Total Cost        3877
# Profit            3674
# Seller              50
# Payment Method       5
# Month               25
# dtype: int64

# %%
d = data.groupby("Category")["Total Cost"].sum()
d
# Out:
# Category
# Beauty            535780.43
# Books             543091.72
# Clothing          536561.64
# Electronics       547419.67
# Home & Kitchen    508740.55
# Toys              527823.08
# Name: Total Cost, dtype: float64

# %%
d = data.groupby("Category")["Total Cost"].sum()

plt.figure(figsize=(10, 6))
plt.scatter(d.index, d.values, color='r', s=90)

plt.title("Total Cost by Category")
plt.xlabel("Category")
plt.ylabel("Total Cost")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

for i, value in enumerate(d.values):
    plt.text(i, value - 2000, f'{value:,.2f}', ha='center', fontsize=9 ,fontweight='bold')

plt.show()

# %% [markdown]
# ## Electronics lead in spending:
# The beauty category has the highest total cost at 912,503.94, indicating it might be the most in-demand or most expensive category.
# Home & Kitchen has the lowest total:¶
# Surprisingly, Home & Kitchen has the lowest total cost, suggesting either lower prices or less consumer interest.

# %%
e = data.groupby("City")[["Total Sales", "Profit"]].sum()
e
# Out:
#               Total Sales   Profit
# City
# Aaronburgh         838.88   365.40
# Aaronmouth         362.12    41.44
# Abbottland        1653.52   573.84
# Abigailmouth      1963.72   616.56
# Abigailstad       1863.32   897.56
# ...                   ...      ...
# Zacharyside       1366.85   196.10
# Zacharystad       1032.28   354.12
# Zacharyton        2124.65  1013.45
# Zavalamouth       1417.08   399.36
# Zoeshire          1381.28   424.88
#
# [3527 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group by city and calculate sum of Total Sales and Profit
data1 = data.groupby("City")[["Total Sales", "Profit"]].sum().sort_values("Total Sales", ascending=False).head(10).reset_index()

# Bin profit for hue in the new grouped data1
data1["Profit Level"] = pd.qcut(data1["Profit"], 3, labels=["Low", "Medium", "High"])

# Seaborn barplot
plt.figure(figsize=(10, 6))
sns.barplot(data=data1, x="City", y="Total Sales", hue="Profit Level", palette="Greens")

plt.title("Top 10 Cities by Sales with Profit Hue")
plt.xticks(rotation=45)
plt.tight_layout()

# Annotate each bar with the total sales value
for i, row in data1.iterrows():
    plt.text(i, row["Total Sales"] + 50, f'{int(row["Total Sales"])}', ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.show()

# %%
data
# Out:
#        Order ID Order Date Delivery Date Customer ID       Customer Name  \
# 4     ORD100004 2025-01-02    2025-01-11    CUST9785     Brandon Hopkins
# 5     ORD100005 2025-02-14    2025-02-19    CUST2139         Megan Joyce
# 8     ORD100008 2025-01-24    2025-02-03    CUST4598      Brandon Molina
# 10    ORD100010 2023-11-07    2023-11-11    CUST5339     Rachel Mitchell
# 11    ORD100011 2023-10-02    2023-10-09    CUST4593      Lauren Daniels
# ...         ...        ...           ...         ...                 ...
# 9992  ORD109992 2023-08-27    2023-09-04    CUST6733      Michael Howell
# 9994  ORD109994 2025-02-16    2025-02-19    CUST1733           Jay Curry
# 9995  ORD109995 2023-08-15    2023-08-24    CUST9689        Chad Johnson
# 9997  ORD109997 2023-05-23    2023-06-02    CUST7324  Christina Olson MD
# 9998  ORD109998 2024-10-27    2024-11-06    CUST5127        Alex Stewart
#
#                     City     Category      Product  Quantity  Unit Price  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Load the CSV file
z = "Amazon_sales.csv"  # Replace this with your actual file path
df = pd.read_csv(z)

# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Group by month and sum the Total Sales
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Total Sales'].sum().sort_index()
monthly_sales.index = monthly_sales.index.to_timestamp()  # For plotting

# Fit Holt-Winters Exponential Smoothing model
model = ExponentialSmoothing(
    monthly_sales,
    trend='add',
    seasonal='add',
    seasonal_periods=12,
    damped_trend=True,  # Optionally, try damped trend
    maxiter=1000  # Increase the max iterations
)
fit = model.fit()

# Forecast the next 6 months
forecast_index = pd.date_range(start=monthly_sales.index[-1] + pd.Timedelta(days=1), periods=6, freq='ME')  # Changed 'M' to 'ME'
forecast = fit.forecast(6)
forecast.index = forecast_index

# Plot the actual and forecasted data
plt.figure(figsize=(10, 8))
plt.plot(monthly_sales.index, monthly_sales.values, label='Historical Sales', marker='o')
plt.plot(forecast.index, forecast.values, label='Forecast (Next 6 Months)', marker='o', linestyle='--', color='orange')
plt.title('Monthly Total Sales with 6-Month Forecast')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 17
#      14 monthly_sales.index = monthly_sales.index.to_timestamp()  # For plotting
#      16 # Fit Holt-Winters Exponential Smoothing model
# ---> 17 model = ExponentialSmoothing(
#      18     monthly_sales,
#      19     trend='add',
#      20     seasonal='add',
#      21     seasonal_periods=12,
#      22     damped_trend=True,  # Optionally, try damped trend
#      23     maxiter=1000  # Increase the max iterations
#      24 )
#      25 fit = model.fit()
#      27 # Forecast the next 6 months
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ### 1. High Sales ≠ High Profit
#
# * Some cities may have high total sales but only "Low" or "Medium" profit levels.
#
# * This could indicate higher costs, discounts, or low-margin products sold in those cities.

# %% [markdown]
# ###   Top 3  cities generating the heighest profit:
# *  Port David
# *  New Robert
# *  north Michael

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Step 1: Load and prepare the data
df = pd.read_csv('Amazon_sales.csv')  # Replace with your actual file path

# Convert 'Order Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Group by month and sum the 'Total Sales'
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Total Sales'].sum().sort_index()

# Convert period index to timestamp for easier plotting
monthly_sales.index = monthly_sales.index.to_timestamp()

# Step 2: Visualize the data (initial view of trend)
plt.figure(figsize=(10, 6))
plt.plot(monthly_sales.index, monthly_sales.values)
plt.title("Monthly Total Sales (Initial View)")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# Step 3: Fit the ARIMA model
# (p, d, q) - p: number of lag observations, d: number of differencing, q: size of moving average window
# You can experiment with different (p, d, q) values for better forecasting

model = ARIMA(monthly_sales, order=(5, 1, 0))  # Example parameters (p=5, d=1, q=0)
fit = model.fit()

# Step 4: Forecast the next 36 months (3 years)
forecast = fit.forecast(steps=36)

# Step 5: Create a future time index for the next 36 months
forecast_index = pd.date_range(monthly_sales.index[-1], periods=37, freq='M')[1:]

# Step 6: Plot the historical data and forecast
plt.figure(figsize=(12, 8))
plt.plot(monthly_sales.index, monthly_sales.values, label='Historical Sales', marker='o')
plt.plot(forecast_index, forecast, label='Forecast (Next 3 Years)', marker='o', linestyle='--', color='orange')
plt.title('ARIMA Forecast for Monthly Total Sales with 3-Year Forecast')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\prince\AppData\Local\Temp\ipykernel_18428\1301524388.py:38: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   forecast_index = pd.date_range(monthly_sales.index[-1], periods=37, freq='M')[1:]

# %%
print(df.isnull().sum())  # Check for missing values
# Out:
# Order ID          0
# Order Date        0
# Delivery Date     0
# Customer ID       0
# Customer Name     0
# City              0
# Category          0
# Product           0
# Quantity          0
# Unit Price        0
# Total Sales       0
# Total Cost        0
# Profit            0
# Seller            0
# Payment Method    0
# dtype: int64

# %%
forecast_index = pd.date_range(monthly_sales.index[-1], periods=37, freq='ME')[1:]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Step 1: Load and prepare the data
df = pd.read_csv('Amazon_sales.csv')  # Replace with your actual file path

# Convert 'Order Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Group by month and sum the 'Total Sales'
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Total Sales'].sum().sort_index()

# Convert period index to timestamp for easier plotting
monthly_sales.index = monthly_sales.index.to_timestamp()

# Step 2: Visualize the data (initial view of trend)
plt.figure(figsize=(10, 6))
plt.plot(monthly_sales.index, monthly_sales.values)
plt.title("Monthly Total Sales (Initial View)")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# Step 3: Fit the model for trend analysis (no seasonal component)
model = ExponentialSmoothing(monthly_sales, trend='add', seasonal=None, seasonal_periods=12)
fit = model.fit()

# Step 4: Forecast the next 36 months (3 years) based on the trend
forecast = fit.forecast(36)

# Create a future time index for the next 36 months (Month End frequency)
forecast_index = pd.date_range(monthly_sales.index[-1], periods=37, freq='ME')[1:]

# Step 5: Plot the historical data and the trend-based forecast
plt.figure(figsize=(12, 8))
plt.plot(monthly_sales.index, monthly_sales.values, label='Historical Sales', marker='o')
plt.plot(forecast_index, forecast.values, label='Forecast (Next 3 Years)', marker='o', linestyle='--', color='orange')
plt.title('Trend Analysis for Monthly Total Sales with 3-Year Forecast')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\holtwinters\model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
